# %% [markdown]
# # 02 · Exploratory Data Analysis
#
# Every figure is tied to a pricing implication. Key finding: in Shenzhen, charging **occupancy peaks overnight**, not at commute hours — so peak windows must come from charging data, not traffic intuition. The Tariff Agent therefore prices on *realized* utilization, not the clock.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from src.eda import run_eda
summary = run_eda()
summary
# Out:
#                     metric      value
# 0       urbanev_peak_hours  [1, 0, 6]
# 1        urbanev_mean_util       0.28
# 2            acn_mean_util      0.877
# 3        urbanev_util_peak      0.326
# 4          urbanev_cv_peak      0.597
# 5    urbanev_util_shoulder      0.276
# 6      urbanev_cv_shoulder      0.603
# 7     urbanev_util_offpeak      0.238
# 8       urbanev_cv_offpeak      0.618
# 9   dynamic_grid_price_std       0.22
# 10   static_grid_price_std      0.162
# 11           cbd_mean_util      0.243
# 12        noncbd_mean_util      0.293
# 13      acn_median_idle_hr       0.74

# %% [markdown]
# ### Figures
# Saved to `outputs/figures/`.

# %%
from IPython.display import Image, display
import glob
for f in sorted(glob.glob('../outputs/figures/*.png')):
    display(Image(f))
